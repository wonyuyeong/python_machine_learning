# %% [markdown]
# # 06. SVM(Supper Vector Machine)의 이해
# ## 선형적 문제 : 두 클래스(또는 두 그룹)을 직선이나 평면과 같은 단순한 경계로 분할 수 있는 문제
#
# > LinearSVC 선형분류기 사용

# %%
from IPython.display import Image
Image("img/img/img06_01.png")

# %% [markdown]
# ## 비선형적 문제 : 두 클래스를 단순한 직선이나 평면으로 분리 할 수 없는 문제
#
# > - 곡선이나 더 복잡한 경계를 사용해야 두 클래스를 나눌 수 있다.
# > - 커널트릭 SVM 사용

# %%
from IPython.display import Image
Image("img/img/img06_02.png")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, RobustScaler
from sklearn.svm import LinearSVC
import pandas as pd
import seaborn as sns

# %%
# 타이타닉 데이터 로드 및 초기정보 확인
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
